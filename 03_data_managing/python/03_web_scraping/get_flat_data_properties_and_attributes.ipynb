# %% [markdown]
# Get Flat Data: Adding New Properties And Attributes
# ===========

# %%
import pandas as pd
import warnings

import nbimporter
import get_flat_data_functions_noChangeIP as flat

warnings.filterwarnings('ignore')
# Out:
# Importing Jupyter notebook from get_flat_data_functions_noChangeIP.ipynb

# %%
for city in ['mostoles']:
    flat.get_properties(city)
    flat.write_new_attributes(city)
# Out:
# There are 679 properties in mostoles
# There are 23 pages in the first search page
# 1 / 23
# 39650866
# 39650939
# 38606416
# 38606298
# 38606301
# 39033156
# 39622282
# 39055533
# 39552696
# 39376213
# 37406512
# 34664666
# 36854555
# 38677343
# 37912184
# 37912068
# 38223817
# 39605521
# 38536199
# 39704534
# 39675327
# 38107512
# 39412797
# 35738088
# 39519289
# 39430420
# 39148773
# 39568949
# 38516310
# 39465145
# 458.000€
# 293.000€
# 212.255€
# 217.970€
# 216.887€
# 376.000€
# 120.000€
# 146.000€
# 139.900€
# 279.900€
# 320.000€
# 246.000€
# 199.000€
# 220.000€
# 199.900€
# 142.000€
# 147.000€
# 199.000€
# 260.000€
# 132.000€
# 149.500€
# 159.000€
# 155.000€
# 69.500€
# 249.990€
# 198.900€
# 179.000€
# 189.000€
# 287.990€
# 89.500€
# 2 / 23
# 39045853
# 39537923
# 36894029
# 39596009
# 39406546
# 39372615
# 38898713
# 39647982
# 39477691
# 38623308
# 39566483
# 39380778
# 39351540
# 38499868
# 38660760
# 39568043
# 39693224
# 38660777
# 38660766
# 38660649
# 39743847
# ...

# %%
flat.write_new_attributes("mostoles")
# Out:
# There are 149 new properties
# https://www.idealista.com/inmueble/39033119/
# 1 / 149
# 78.30.12.218
# 39033119
# [None]
# https://www.idealista.com/inmueble/38842172/
# 2 / 149
# 78.30.12.218
# 38842172
# 200.000
# https://www.idealista.com/inmueble/39076291/
# 3 / 149
# 78.30.12.218
# 39076291
# [None]
# https://www.idealista.com/inmueble/39194668/
# 4 / 149
# 78.30.12.218
# 39194668
# [None]
# https://www.idealista.com/inmueble/39596256/
# 5 / 149
# 78.30.12.218
# 39596256
# [None]
# https://www.idealista.com/inmueble/29221317/
# 6 / 149
# 78.30.12.218
# 29221317
# [None]
# https://www.idealista.com/inmueble/39637841/
# 7 / 149
# 78.30.12.218
# 39637841
# [None]
# https://www.idealista.com/inmueble/39637822/
# 8 / 149
# 78.30.12.218
# 39637822
# [None]
# https://www.idealista.com/inmueble/39637811/
# 9 / 149
# 78.30.12.218
# 39637811
# [None]
# https://www.idealista.com/inmueble/39033164/
# 10 / 149
# 78.30.12.218
# 39033164
# [None]
# https://www.idealista.com/inmueble/39076365/
# ...
