# %% [markdown]
# Exploring Travel Data: A practical introduction to Pandas
# ===================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use("ggplot")

# %% [markdown]
# We have been asked to *analyze an otp dataset*, without much more information. This kind of scenario is more common than you might imagine!
#
# ## 1) Quickly examine the files in ~/Data/otp. What do they contain, in both technical and functional terms? (Use any tool you want)

# %%
pwd
# Out:
# '/home/dsc/Documents/repos-ja/masterDataScience/python/02_data_managing'

# %%
path = "../../data/otp/"

# %%
# !ls {path}
# Out:
# On_Time_On_Time_Performance_2015_1.zip	On_Time_On_Time_Performance_2015_5.zip
# On_Time_On_Time_Performance_2015_2.zip	On_Time_On_Time_Performance_2015_6.zip
# On_Time_On_Time_Performance_2015_3.zip	On_Time_On_Time_Performance_2015_7.zip
# On_Time_On_Time_Performance_2015_4.zip	On_Time_On_Time_Performance_2015_8.zip

# %% [markdown]
# For this example, we are going to begin using the shell from within this notebook, with the ! notation:
#
# A ! sign before a line tells the notebook to send that line straight away to the underlying OS.
#
# \* Note that we can substitute python variables into the shell command. We do that by surrounding the name of the variable with curly braces ({}). That's what we are going to do with the `path_to_files` variable

# %% [markdown]
# ### Check what the files contain

# %%
# !unzip -l $path/On_Time_On_Time_Performance_2015_1.zip
# Out:
# Archive:  /home/dsc/Documents/python_ScientificStack/data/otp//On_Time_On_Time_Performance_2015_1.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
# 211633432  04-16-2015 20:02   On_Time_On_Time_Performance_2015_1.csv
#     12054  04-16-2015 20:02   readme.html
# ---------                     -------
# 211645486                     2 files

# %% [markdown]
# Oh, it has a readme! Always good to read it.

# %% [markdown]
# ### Unzip the readme to the current directory
#
# Use the shell
#
# Remember, since the zip file contains several compressed files, we need to specify which one we want.

# %%
# !unzip -o $path/On_Time_On_Time_Performance_2015_1.zip readme.html -d ./data/
# Out:
# Archive:  /home/dsc/Documents/python_ScientificStack/data/otp//On_Time_On_Time_Performance_2015_1.zip
#   inflating: ./data/readme.html

# %%
# !ls ./data/
# Out:
# 914310910_T_T100_SEGMENT_ALL_CARRIER_2015_All.csv  otp
# 914310910_T_T100_SEGMENT_ALL_CARRIER_ReadMe.csv    readme.html
# 914310910_T_T100_SEGMENT_ALL_CARRIER_Terms.csv	   tips.csv
# houses.csv					   train.csv
# On_Time_On_Time_Performance_2015_1.csv		   weather_year.csv

# %% [markdown]
# ### Take a look at the beginning of the readme file
#
# using the shell

# %%
# !cat ./data/readme.html
# Out:
# <HTML>
# <HEAD>
# 	<TITLE> readme.html </TITLE>
# </HEAD>
# <BODY>
# 	<TABLE><TR><TD COLSPAN=2><H4>BACKGROUND</H4></TD></TR>
# 	<TR><TD COLSPAN=2>The data contained in the compressed file has been extracted from the
# 	On-Time Performance data table of the "On-Time" database from the TranStats data library.
# 	The time period is indicated in the name of the compressed file;
# 	for example, XXX_XXXXX_2001_1 contains data of the first month of the year 2001. </TD></TR>
# 	<TR><TD COLSPAN=2>&nbsp;</TD></TR>
# 	<TR><TD COLSPAN=2><H4>RECORD LAYOUT</H4></TD></TR>
# 	<TR><TD COLSPAN=2>Below are fields in the order that they appear on the records:</TD></TR>
# 	<TR><TD>Year</TD><TD>Year</TD></TR>
# 	<TR><TD>Quarter</TD><TD>Quarter (1-4)</TD></TR>
# 	<TR><TD>Month</TD><TD>Month</TD></TR>
# 	<TR><TD>DayofMonth</TD><TD>Day of Month</TD></TR>
# 	<TR><TD>DayOfWeek</TD><TD>Day of Week</TD></TR>
# 	<TR><TD>FlightDate</TD><TD>Flight Date (yyyymmdd)</TD></TR>
# 	<TR><TD>UniqueCarrier</TD><TD>Unique Carrier Code. When the same code has been used by multiple carriers, a numeric suffix is used for earlier users, for example, PA, PA(1), PA(2). Use this field for analysis across a range of years.</TD></TR>
# 	<TR><TD>AirlineID</TD><TD>An identification number assigned by US DOT to identify a unique airline (carrier). A unique airline (carrier) is defined as one holding and reporting under the same DOT certificate regardless of its Code, Name, or holding company/corporation.</TD></TR>
# 	<TR><TD>Carrier</TD><TD>Code assigned by IATA and commonly used to identify a carrier. As the same code may have been assigned to different carriers over time, the code is not always unique. For analysis, use the Unique Carrier Code.</TD></TR>
# 	<TR><TD>TailNum</TD><TD>Tail Number</TD></TR>
# 	<TR><TD>FlightNum</TD><TD>Flight Number</TD></TR>
# 	<TR><TD>OriginAirportID</TD><TD>Origin Airport, Airport ID. An identification number assigned by US DOT to identify a unique airport.  Use this field for airport analysis across a range of years because an airport can change its airport code and airport codes can be reused.</TD></TR>
# 	<TR><TD>OriginAirportSeqID</TD><TD>Origin Airport, Airport Sequence ID. An identification number assigned by US DOT to identify a unique airport at a given point of time.  Airport attributes, such as airport name or coordinates, may change over time.</TD></TR>
# 	<TR><TD>OriginCityMarketID</TD><TD>Origin Airport, City Market ID. City Market ID is an identification number assigned by US DOT to identify a city market.  Use this field to consolidate airports serving the same city market.</TD></TR>
# 	<TR><TD>Origin</TD><TD>Origin Airport</TD></TR>
# 	<TR><TD>OriginCityName</TD><TD>Origin Airport, City Name</TD></TR>
# 	<TR><TD>OriginState</TD><TD>Origin Airport, State Code</TD></TR>
# 	<TR><TD>OriginStateFips</TD><TD>Origin Airport, State Fips</TD></TR>
# 	<TR><TD>OriginStateName</TD><TD>Origin Airport, State Name</TD></TR>
# 	<TR><TD>OriginWac</TD><TD>Origin Airport, World Area Code</TD></TR>
# 	<TR><TD>DestAirportID</TD><TD>Destination Airport, Airport ID. An identification number assigned by US DOT to identify a unique airport.  Use this field for airport analysis across a range of years because an airport can change its airport code and airport codes can be reused.</TD></TR>
# 	<TR><TD>DestAirportSeqID</TD><TD>Destination Airport, Airport Sequence ID. An identification number assigned by US DOT to identify a unique airport at a given point of time.  Airport attributes, such as airport name or coordinates, may change over time.</TD></TR>
# 	<TR><TD>DestCityMarketID</TD><TD>Destination Airport, City Market ID. City Market ID is an identification number assigned by US DOT to identify a city market.  Use this field to consolidate airports serving the same city market.</TD></TR>
# 	<TR><TD>Dest</TD><TD>Destination Airport</TD></TR>
# 	<TR><TD>DestCityName</TD><TD>Destination Airport, City Name</TD></TR>
# 	<TR><TD>DestState</TD><TD>Destination Airport, State Code</TD></TR>
# 	<TR><TD>DestStateFips</TD><TD>Destination Airport, State Fips</TD></TR>
# 	<TR><TD>DestStateName</TD><TD>Destination Airport, State Name</TD></TR>
# 	<TR><TD>DestWac</TD><TD>Destination Airport, World Area Code</TD></TR>
# 	<TR><TD>CRSDepTime</TD><TD>CRS Departure Time (local time: hhmm)</TD></TR>
# 	<TR><TD>DepTime</TD><TD>Actual Departure Time (local time: hhmm)</TD></TR>
# 	<TR><TD>DepDelay</TD><TD>Difference in minutes between scheduled and actual departure time. Early departures show negative numbers.</TD></TR>
# 	<TR><TD>DepDelayMinutes</TD><TD>Difference in minutes between scheduled and actual departure time. Early departures set to 0.</TD></TR>
# 	<TR><TD>DepDel15</TD><TD>Departure Delay Indicator, 15 Minutes or More (1=Yes)</TD></TR>
# 	<TR><TD>DepartureDelayGroups</TD><TD>Departure Delay intervals, every (15 minutes from <-15 to >180)</TD></TR>
# 	<TR><TD>DepTimeBlk</TD><TD>CRS Departure Time Block, Hourly Intervals</TD></TR>
# 	<TR><TD>TaxiOut</TD><TD>Taxi Out Time, in Minutes</TD></TR>
# 	<TR><TD>WheelsOff</TD><TD>Wheels Off Time (local time: hhmm)</TD></TR>
# 	<TR><TD>WheelsOn</TD><TD>Wheels On Time (local time: hhmm)</TD></TR>
# 	<TR><TD>TaxiIn</TD><TD>Taxi In Time, in Minutes</TD></TR>
# 	<TR><TD>CRSArrTime</TD><TD>CRS Arrival Time (local time: hhmm)</TD></TR>
# 	<TR><TD>ArrTime</TD><TD>Actual Arrival Time (local time: hhmm)</TD></TR>
# 	<TR><TD>ArrDelay</TD><TD>Difference in minutes between scheduled and actual arrival time. Early arrivals show negative numbers.</TD></TR>
# 	<TR><TD>ArrDelayMinutes</TD><TD>Difference in minutes between scheduled and actual arrival time. Early arrivals set to 0.</TD></TR>
# 	<TR><TD>ArrDel15</TD><TD>Arrival Delay Indicator, 15 Minutes or More (1=Yes)</TD></TR>
# 	<TR><TD>ArrivalDelayGroups</TD><TD>Arrival Delay intervals, every (15-minutes from <-15 to >180)</TD></TR>
# 	<TR><TD>ArrTimeBlk</TD><TD>CRS Arrival Time Block, Hourly Intervals</TD></TR>
# 	<TR><TD>Cancelled</TD><TD>Cancelled Flight Indicator (1=Yes)</TD></TR>
# 	<TR><TD>CancellationCode</TD><TD>Specifies The Reason For Cancellation</TD></TR>
# 	<TR><TD>Diverted</TD><TD>Diverted Flight Indicator (1=Yes)</TD></TR>
# 	<TR><TD>CRSElapsedTime</TD><TD>CRS Elapsed Time of Flight, in Minutes</TD></TR>
# 	<TR><TD>ActualElapsedTime</TD><TD>Elapsed Time of Flight, in Minutes</TD></TR>
# 	<TR><TD>AirTime</TD><TD>Flight Time, in Minutes</TD></TR>
# 	<TR><TD>Flights</TD><TD>Number of Flights</TD></TR>
# 	<TR><TD>Distance</TD><TD>Distance between airports (miles)</TD></TR>
# 	<TR><TD>DistanceGroup</TD><TD>Distance Intervals, every 250 Miles, for Flight Segment</TD></TR>
# 	<TR><TD>CarrierDelay</TD><TD>Carrier Delay, in Minutes</TD></TR>
# 	<TR><TD>WeatherDelay</TD><TD>Weather Delay, in Minutes</TD></TR>
# 	<TR><TD>NASDelay</TD><TD>National Air System Delay, in Minutes</TD></TR>
# 	<TR><TD>SecurityDelay</TD><TD>Security Delay, in Minutes</TD></TR>
# 	<TR><TD>LateAircraftDelay</TD><TD>Late Aircraft Delay, in Minutes</TD></TR>
# 	<TR><TD>FirstDepTime</TD><TD>First Gate Departure Time at Origin Airport</TD></TR>
# 	<TR><TD>TotalAddGTime</TD><TD>Total Ground Time Away from Gate for Gate Return or Cancelled Flight</TD></TR>
# 	<TR><TD>LongestAddGTime</TD><TD>Longest Time Away from Gate for Gate Return or Cancelled Flight</TD></TR>
# 	<TR><TD>DivAirportLandings</TD><TD>Number of Diverted Airport Landings</TD></TR>
# 	<TR><TD>DivReachedDest</TD><TD>Diverted Flight Reaching Scheduled Destination Indicator (1=Yes)</TD></TR>
# 	<TR><TD>DivActualElapsedTime</TD><TD>Elapsed Time of Diverted Flight Reaching Scheduled Destination, in Minutes.  The ActualElapsedTime column remains NULL for all diverted flights.</TD></TR>
# 	<TR><TD>DivArrDelay</TD><TD>Difference in minutes between scheduled and actual arrival time for a diverted flight reaching scheduled destination.  The ArrDelay column remains NULL for all diverted flights.</TD></TR>
# 	<TR><TD>DivDistance</TD><TD>Distance between scheduled destination and final diverted airport (miles).  Value will be 0 for diverted flight reaching scheduled destination.</TD></TR>
# 	<TR><TD>Div1Airport</TD><TD>Diverted Airport Code1</TD></TR>
# 	<TR><TD>Div1AirportID</TD><TD>Airport ID of Diverted Airport 1. Airport ID is a Unique Key for an Airport</TD></TR>
# 	<TR><TD>Div1AirportSeqID</TD><TD>Airport Sequence ID of Diverted Airport 1. Unique Key for Time Specific Information for an Airport</TD></TR>
# 	<TR><TD>Div1WheelsOn</TD><TD>Wheels On Time (local time: hhmm) at Diverted Airport Code1</TD></TR>
# 	<TR><TD>Div1TotalGTime</TD><TD>Total Ground Time Away from Gate at Diverted Airport Code1</TD></TR>
# 	<TR><TD>Div1LongestGTime</TD><TD>Longest Ground Time Away from Gate at Diverted Airport Code1</TD></TR>
# 	<TR><TD>Div1WheelsOff</TD><TD>Wheels Off Time (local time: hhmm) at Diverted Airport Code1</TD></TR>
# 	<TR><TD>Div1TailNum</TD><TD>Aircraft Tail Number for Diverted Airport Code1</TD></TR>
# 	<TR><TD>Div2Airport</TD><TD>Diverted Airport Code2</TD></TR>
# 	<TR><TD>Div2AirportID</TD><TD>Airport ID of Diverted Airport 2. Airport ID is a Unique Key for an Airport</TD></TR>
# 	<TR><TD>Div2AirportSeqID</TD><TD>Airport Sequence ID of Diverted Airport 2. Unique Key for Time Specific Information for an Airport</TD></TR>
# 	<TR><TD>Div2WheelsOn</TD><TD>Wheels On Time (local time: hhmm) at Diverted Airport Code2</TD></TR>
# 	<TR><TD>Div2TotalGTime</TD><TD>Total Ground Time Away from Gate at Diverted Airport Code2</TD></TR>
# 	<TR><TD>Div2LongestGTime</TD><TD>Longest Ground Time Away from Gate at Diverted Airport Code2</TD></TR>
# 	<TR><TD>Div2WheelsOff</TD><TD>Wheels Off Time (local time: hhmm) at Diverted Airport Code2</TD></TR>
# 	<TR><TD>Div2TailNum</TD><TD>Aircraft Tail Number for Diverted Airport Code2</TD></TR>
# 	<TR><TD>Div3Airport</TD><TD>Diverted Airport Code3</TD></TR>
# 	<TR><TD>Div3AirportID</TD><TD>Airport ID of Diverted Airport 3. Airport ID is a Unique Key for an Airport</TD></TR>
# 	<TR><TD>Div3AirportSeqID</TD><TD>Airport Sequence ID of Diverted Airport 3. Unique Key for Time Specific Information for an Airport</TD></TR>
# 	<TR><TD>Div3WheelsOn</TD><TD>Wheels On Time (local time: hhmm) at Diverted Airport Code3</TD></TR>
# 	<TR><TD>Div3TotalGTime</TD><TD>Total Ground Time Away from Gate at Diverted Airport Code3</TD></TR>
# 	<TR><TD>Div3LongestGTime</TD><TD>Longest Ground Time Away from Gate at Diverted Airport Code3</TD></TR>
# 	<TR><TD>Div3WheelsOff</TD><TD>Wheels Off Time (local time: hhmm) at Diverted Airport Code3</TD></TR>
# 	<TR><TD>Div3TailNum</TD><TD>Aircraft Tail Number for Diverted Airport Code3</TD></TR>
# 	<TR><TD>Div4Airport</TD><TD>Diverted Airport Code4</TD></TR>
# 	<TR><TD>Div4AirportID</TD><TD>Airport ID of Diverted Airport 4. Airport ID is a Unique Key for an Airport</TD></TR>
# 	<TR><TD>Div4AirportSeqID</TD><TD>Airport Sequence ID of Diverted Airport 4. Unique Key for Time Specific Information for an Airport</TD></TR>
# 	<TR><TD>Div4WheelsOn</TD><TD>Wheels On Time (local time: hhmm) at Diverted Airport Code4</TD></TR>
# 	<TR><TD>Div4TotalGTime</TD><TD>Total Ground Time Away from Gate at Diverted Airport Code4</TD></TR>
# 	<TR><TD>Div4LongestGTime</TD><TD>Longest Ground Time Away from Gate at Diverted Airport Code4</TD></TR>
# 	<TR><TD>Div4WheelsOff</TD><TD>Wheels Off Time (local time: hhmm) at Diverted Airport Code4</TD></TR>
# 	<TR><TD>Div4TailNum</TD><TD>Aircraft Tail Number for Diverted Airport Code4</TD></TR>
# 	<TR><TD>Div5Airport</TD><TD>Diverted Airport Code5</TD></TR>
# 	<TR><TD>Div5AirportID</TD><TD>Airport ID of Diverted Airport 5. Airport ID is a Unique Key for an Airport</TD></TR>
# 	<TR><TD>Div5AirportSeqID</TD><TD>Airport Sequence ID of Diverted Airport 5. Unique Key for Time Specific Information for an Airport</TD></TR>
# 	<TR><TD>Div5WheelsOn</TD><TD>Wheels On Time (local time: hhmm) at Diverted Airport Code5</TD></TR>
# 	<TR><TD>Div5TotalGTime</TD><TD>Total Ground Time Away from Gate at Diverted Airport Code5</TD></TR>
# 	<TR><TD>Div5LongestGTime</TD><TD>Longest Ground Time Away from Gate at Diverted Airport Code5</TD></TR>
# 	<TR><TD>Div5WheelsOff</TD><TD>Wheels Off Time (local time: hhmm) at Diverted Airport Code5</TD></TR>
# 	<TR><TD>Div5TailNum</TD><TD>Aircraft Tail Number for Diverted Airport Code5</TD></TR>
# 	</TABLE>
# </BODY>
# </HTML>

# %% [markdown]
# The readme file is html. Luckily, we are working in an html environment.
#
# ### Display the contents of `readme.html` within the notebook
# (Hint: check out [IPython.display.IFrame](https://ipython.org/ipython-doc/3/api/generated/IPython.display.html))

# %%
from IPython.display import IFrame

# %%
help(IFrame)
# Out:
# Help on class IFrame in module IPython.lib.display:
#
# class IFrame(builtins.object)
#  |  Generic class to embed an iframe in an IPython notebook
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, src, width, height, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  iframe = '\n        <iframe\n            width="{width}"\n   ...      ...

# %%
IFrame('./data/readme.html',800,800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="./data/readme.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# That's some very good documentation!
#
# ### Summary:
#
# The files within the zip are " quoted csv's. They contain information on timeliness of departures in the US, at the departure level.

# %%
filename = "On_Time_On_Time_Performance_2015_1"

# !unzip -o {path}/{filename}.zip {filename}.csv -d ./data/
# Out:
# Archive:  /home/dsc/Documents/python_ScientificStack/data/otp//On_Time_On_Time_Performance_2015_1.zip
#   inflating: ./data/On_Time_On_Time_Performance_2015_1.csv

# %%
# !head -n 2 ./data/On_Time_On_Time_Performance_2015_1.csv
# Out:
# "Year","Quarter","Month","DayofMonth","DayOfWeek","FlightDate","UniqueCarrier","AirlineID","Carrier","TailNum","FlightNum","OriginAirportID","OriginAirportSeqID","OriginCityMarketID","Origin","OriginCityName","OriginState","OriginStateFips","OriginStateName","OriginWac","DestAirportID","DestAirportSeqID","DestCityMarketID","Dest","DestCityName","DestState","DestStateFips","DestStateName","DestWac","CRSDepTime","DepTime","DepDelay","DepDelayMinutes","DepDel15","DepartureDelayGroups","DepTimeBlk","TaxiOut","WheelsOff","WheelsOn","TaxiIn","CRSArrTime","ArrTime","ArrDelay","ArrDelayMinutes","ArrDel15","ArrivalDelayGroups","ArrTimeBlk","Cancelled","CancellationCode","Diverted","CRSElapsedTime","ActualElapsedTime","AirTime","Flights","Distance","DistanceGroup","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay","LateAircraftDelay","FirstDepTime","TotalAddGTime","LongestAddGTime","DivAirportLandings","DivReachedDest","DivActualElapsedTime","DivArrDelay","DivDistance","Div1Airport","Div1AirportID","Div1AirportSeqID","Div1WheelsOn","Div1TotalGTime","Div1LongestGTime","Div1WheelsOff","Div1TailNum","Div2Airport","Div2AirportID","Div2AirportSeqID","Div2WheelsOn","Div2TotalGTime","Div2LongestGTime","Div2WheelsOff","Div2TailNum","Div3Airport","Div3AirportID","Div3AirportSeqID","Div3WheelsOn","Div3TotalGTime","Div3LongestGTime","Div3WheelsOff","Div3TailNum","Div4Airport","Div4AirportID","Div4AirportSeqID","Div4WheelsOn","Div4TotalGTime","Div4LongestGTime","Div4WheelsOff","Div4TailNum","Div5Airport","Div5AirportID","Div5AirportSeqID","Div5WheelsOn","Div5TotalGTime","Div5LongestGTime","Div5WheelsOff","Div5TailNum",
# 2015,1,1,1,4,2015-01-01,"AA",19805,"AA","N787AA","1",12478,1247802,31703,"JFK","New York, NY","NY","36","New York",22,12892,1289203,32575,"LAX","Los Angeles, CA","CA","06","California",91,"0900","0855",-5.00,0.00,0.00,-1,"0900-0959",17.00,"0912","1230",7.00,"1230","1237",7.00,7.00,0.00,0,"1200-1259",0.00,"",0.00,390.00,402.00,378.00,1.00,2475.00,10,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",

# %% [markdown]
# Pretty unreadable, so we go for a tool designed specifically for tabular data: **pandas**

# %% [markdown]
# ### Load some of the data (one of the files) into memory as a pandas dataframe. What functions do you need to use?
#
# Pro tip: there is no need to decompress the whole file. Check out zipfile.ZipFile

# %% [markdown]
# First, open a connection to one of the files

# %%
readme = open("./data/readme.html")
readme
# Out:
# <_io.TextIOWrapper name='./data/readme.html' mode='r' encoding='UTF-8'>

# %%
from zipfile import ZipFile

my_zip_file = ZipFile(path + filename + ".zip")
type(my_zip_file)
# Out:
# zipfile.ZipFile

# %% [markdown]
# zip_file is a connection to the compressed file, the .zip. We can use it to open a connection to one of the files it contains, which will behave like a normal uncompressed file that we had opened with open()

# %% [markdown]
# Now we're ready to load the file into memory as a pandas dataframe. Remember to close the connections to the files!

# %%
# These two lines of code have to be in the same chunk in order to open, read and close the zip file. 
# Otherwise, we will not be able to read the zip file if we have not previouly opened it
my_csv_file = my_zip_file.open(filename + ".csv")
df = pd.read_csv(my_csv_file)
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Let's start examining the data: show the beginning of the file. How many records does it contain?

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2015        1      1           1          4  2015-01-01            AA
# 1  2015        1      1           2          5  2015-01-02            AA
# 2  2015        1      1           3          6  2015-01-03            AA
# 3  2015        1      1           4          7  2015-01-04            AA
# 4  2015        1      1           5          1  2015-01-05            AA
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0      19805      AA  N787AA      ...               NaN          NaN
# 1      19805      AA  N795AA      ...               NaN          NaN
# 2      19805      AA  N788AA      ...               NaN          NaN
# 3      19805      AA  N791AA      ...               NaN          NaN
# 4      19805      AA  N783AA      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 0            NaN               NaN          NaN            NaN
# 1            NaN               NaN          NaN            NaN
# 2            NaN               NaN          NaN            NaN
# 3            NaN               NaN          NaN            NaN
# 4            NaN               NaN          NaN            NaN
#
#   Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0              NaN            NaN         NaN           NaN
# 1              NaN            NaN         NaN           NaN
# 2              NaN            NaN         NaN           NaN
# 3              NaN            NaN         NaN           NaN
# 4              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
df.shape
# Out:
# (469968, 110)

# %% [markdown]
# ## Trimming the data
#
# The table is quite wide, and it seems that there are many columns without much data. Which, exactly, are those? (let's consider empty a column that doesn't contain at least 1000 records, arbitrarily)

# %%
df.columns[df.count() <= 1000]
# Out:
# Index(['DivReachedDest', 'DivActualElapsedTime', 'DivArrDelay', 'DivDistance',
#        'Div1WheelsOff', 'Div1TailNum', 'Div2Airport', 'Div2AirportID',
#        'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime',
#        'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum', 'Div3Airport',
#        'Div3AirportID', 'Div3AirportSeqID', 'Div3WheelsOn', 'Div3TotalGTime',
#        'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum', 'Div4Airport',
#        'Div4AirportID', 'Div4AirportSeqID', 'Div4WheelsOn', 'Div4TotalGTime',
#        'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum', 'Div5Airport',
#        'Div5AirportID', 'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime',
#        'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum', 'Unnamed: 109'],
#       dtype='object')

# %%
columns_to_keep = df.columns[df.count() > 1000]
#Other way to do it: df.notnull().sum() instead of df.count()

# %%
df = df[columns_to_keep]
df.shape
# Out:
# (469968, 71)

# %% [markdown]
# It seems that the "diverted" fields, after the first, are often empty. No big surprise, since not that many flights must be diverted more than once in a month. Let's drop those columns, since we are not that interested in those, at least for now.

# %%
df = df[df.columns[~df.columns.str.contains("Div")]]

# %%
df.shape
# Out:
# (469968, 63)

# %% [markdown]
# Now that we have eliminated some inconvenient data columns, let's have a look at the rest: let's loook at how the location data is encoded.

# %% [markdown]
# #### Exercise:
#
# First, generate a list of the columns that have 'Origin' in their name
#
# Second, show a sample of the values that those columns take.
#
# Hint: we are going to use the str attribute of Series and Indexes

# %%
columns_with_origin = df.columns[df.columns.str.contains("Origin")]
df[columns_with_origin].sample(5)
# Out:
#         OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 422777            14843             1484304               34819    SJU
# 314713            15376             1537602               30436    TUS
# 261572            13127             1312702               33127    LWS
# 197394            15304             1530402               33195    TPA
# 324459            11292             1129202               30325    DEN
#
#        OriginCityName OriginState  OriginStateFips OriginStateName  OriginWac
# 422777   San Juan, PR          PR               72     Puerto Rico          3
# 314713     Tucson, AZ          AZ                4         Arizona         81
# 261572   Lewiston, ID          ID               16           Idaho         83
# 197394      Tampa, FL          FL               12         Florida         33
# 324459     Denver, CO          CO                8        Colorado         82

# %% [markdown]
# So much redundant information!

# %% [markdown]
# ## Fast forward
#
# Just taking out the redundant columns would take a while, so let's jump ahead with this list of interesting columns:

# %%
columns_of_interest = ['FlightDate', 'DayOfWeek', 'Carrier', 'TailNum', 'FlightNum', 'Origin', 
                       'OriginCityName', 'OriginStateName', 'Dest', 'DestCityName', 'DestStateName',
                       'DepTime', 'DepDelay', 'AirTime', 'Distance']

df = df[columns_of_interest]

# %%
df.shape
# Out:
# (469968, 15)

# %% [markdown]
# ## Formatting columns and parsing dates and times
#
# Hurray! we have almost cleaned our dataset. Soon we will begin to do some actual work with it.

# %%
df.dtypes
# Out:
# FlightDate          object
# DayOfWeek            int64
# Carrier             object
# TailNum             object
# FlightNum            int64
# Origin              object
# OriginCityName      object
# OriginStateName     object
# Dest                object
# DestCityName        object
# DestStateName       object
# DepTime            float64
# DepDelay           float64
# AirTime            float64
# Distance           float64
# dtype: object

# %% [markdown]
# Pandas interpreted the Deptime column as ints and the FlighDate column as strings. We want to combine them and parse them into a DateTime column, so that we can use them properly as datetimes.

# %% [markdown]
# First step:
#
# #### Exercise
#
# Define a function that will parse our int hours into a reasonable format ("HH:MM"). It should take only one int hour and return the appropriate representation.

# %%
df['DepTime'][0]
# Out:
# 855.0

# %%
def float_to_timestring(input_float):
    
    if np.isnan(input_float):
        input_float = 0.0
    
    minutes = input_float % 100
    hours = (input_float // 100) % 24 # In order to obtain 00:00 instaed of 24:00
    string_representation = '%.2d:%.2d' % (hours,minutes)
    
    return string_representation

# Checking function:
print(float_to_timestring(355.0))
print(float_to_timestring(np.nan))
print(float_to_timestring(2400.0))
# Out:
# 03:55
# 00:00
# 00:00

# %% [markdown]
# Now, we can use that function to build datetime strings that we will then pass to pd.to_datetime, with a format we will specify. Let's do that
#
# Hint: Check out [pd.to_datetime's documentatoin](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) for info on the acceptable format.

# %%
deptime_strings = df['DepTime'].apply(float_to_timestring)

# %% [markdown]
# #### Exercise
#
# Overwrite the 'DepTime' column with its version in the proper format
#
# Hint: Before overwriting your column in the dataframe, make sure that everything works by assigning the modified column to a Series variable.

# %%
df['DepTime'] = pd.Series(deptime_strings)

# %%
df.head()
# Out:
#    FlightDate  DayOfWeek Carrier TailNum  FlightNum Origin OriginCityName  \
# 0  2015-01-01          4      AA  N787AA          1    JFK   New York, NY
# 1  2015-01-02          5      AA  N795AA          1    JFK   New York, NY
# 2  2015-01-03          6      AA  N788AA          1    JFK   New York, NY
# 3  2015-01-04          7      AA  N791AA          1    JFK   New York, NY
# 4  2015-01-05          1      AA  N783AA          1    JFK   New York, NY
#
#   OriginStateName Dest     DestCityName DestStateName DepTime  DepDelay  \
# 0        New York  LAX  Los Angeles, CA    California   08:55      -5.0
# 1        New York  LAX  Los Angeles, CA    California   08:50     -10.0
# 2        New York  LAX  Los Angeles, CA    California   08:53      -7.0
# 3        New York  LAX  Los Angeles, CA    California   08:53      -7.0
# 4        New York  LAX  Los Angeles, CA    California   08:53      -7.0
#
#    AirTime  Distance
# 0    378.0    2475.0
# 1    357.0    2475.0
# 2    330.0    2475.0
# 3    352.0    2475.0
# 4    338.0    2475.0

# %% [markdown]
# #### Exercise
#
# Now, create a DepDateTime with the proper type using `pd.to_datetime`

# %%
df['DepDateTime'] = pd.to_datetime(df['FlightDate']+" "+df['DepTime'])

# %%
df.head()
# Out:
#    FlightDate  DayOfWeek Carrier TailNum  FlightNum Origin OriginCityName  \
# 0  2015-01-01          4      AA  N787AA          1    JFK   New York, NY
# 1  2015-01-02          5      AA  N795AA          1    JFK   New York, NY
# 2  2015-01-03          6      AA  N788AA          1    JFK   New York, NY
# 3  2015-01-04          7      AA  N791AA          1    JFK   New York, NY
# 4  2015-01-05          1      AA  N783AA          1    JFK   New York, NY
#
#   OriginStateName Dest     DestCityName DestStateName DepTime  DepDelay  \
# 0        New York  LAX  Los Angeles, CA    California   08:55      -5.0
# 1        New York  LAX  Los Angeles, CA    California   08:50     -10.0
# 2        New York  LAX  Los Angeles, CA    California   08:53      -7.0
# 3        New York  LAX  Los Angeles, CA    California   08:53      -7.0
# 4        New York  LAX  Los Angeles, CA    California   08:53      -7.0
#
#    AirTime  Distance         DepDateTime
# 0    378.0    2475.0 2015-01-01 08:55:00
# 1    357.0    2475.0 2015-01-02 08:50:00
# 2    330.0    2475.0 2015-01-03 08:53:00
# 3    352.0    2475.0 2015-01-04 08:53:00
# 4    338.0    2475.0 2015-01-05 08:53:00

# %% [markdown]
# ### Inspect the types, see if everything is in order

# %%
df.dtypes
# Out:
# FlightDate                 object
# DayOfWeek                   int64
# Carrier                    object
# TailNum                    object
# FlightNum                   int64
# Origin                     object
# OriginCityName             object
# OriginStateName            object
# Dest                       object
# DestCityName               object
# DestStateName              object
# DepTime                    object
# DepDelay                  float64
# AirTime                   float64
# Distance                  float64
# DepDateTime        datetime64[ns]
# dtype: object

# %% [markdown]
# ## Examining the data

# %% [markdown]
# Finally clean! Let's start to do some preliminary work on the data.

# %% [markdown]
# #### Exercise:
#
# Find the biggest delays.
#
# How would you find the 5 maximum delays?

# %%
df.sort_values('DepDelay',ascending = False).head(5)
# Out:
#         FlightDate  DayOfWeek Carrier TailNum  FlightNum Origin  \
# 21523   2015-01-23          5      AA  N598AA       1322    BHM
# 11524   2015-01-18          7      AA  N5DGAA        224    LAS
# 18198   2015-01-27          2      AA  N586AA       1242    FAT
# 108152  2015-01-21          3      AA  N4XNAA       2385    JAX
# 26001   2015-01-11          7      AA  N469AA       1595    AUS
#
#           OriginCityName OriginStateName Dest           DestCityName  \
# 21523     Birmingham, AL         Alabama  DFW  Dallas/Fort Worth, TX
# 11524      Las Vegas, NV          Nevada  LAX        Los Angeles, CA
# 18198         Fresno, CA      California  DFW  Dallas/Fort Worth, TX
# 108152  Jacksonville, FL         Florida  DFW  Dallas/Fort Worth, TX
# 26001         Austin, TX           Texas  DFW  Dallas/Fort Worth, TX
#
#        DestStateName DepTime  DepDelay  AirTime  Distance         DepDateTime
# 21523          Texas   16:08    1988.0     99.0     597.0 2015-01-23 16:08:00
# 11524     California   14:14    1604.0     42.0     236.0 2015-01-18 14:14:00
# 18198          Texas   08:50    1551.0    155.0    1313.0 2015-01-27 08:50:00
# 108152         Texas   12:40    1457.0    144.0     918.0 2015-01-21 12:40:00
# 26001          Texas   07:00    1450.0     37.0     190.0 2015-01-11 07:00:00

# %% [markdown]
# #### Exercise
#
# What was the average delay for this month? Standard deviation and typical value?

# %%
df.describe()
# Out:
#            DayOfWeek      FlightNum       DepDelay        AirTime  \
# count  469968.000000  469968.000000  458311.000000  457013.000000
# mean        4.025559    2266.351901       9.759471     112.544096
# std         1.933772    1804.269617      36.636491      71.682848
# min         1.000000       1.000000     -48.000000       8.000000
# 25%         2.000000     760.000000      -5.000000      60.000000
# 50%         4.000000    1735.000000      -2.000000      94.000000
# 75%         6.000000    3488.000000       9.000000     144.000000
# max         7.000000    9793.000000    1988.000000     676.000000
#
#             Distance
# count  469968.000000
# mean      803.261279
# std       596.249383
# min        31.000000
# 25%       366.000000
# 50%       641.000000
# 75%      1046.000000
# max      4983.000000

# %%
# Most frequent delay
df['DepDelay'].value_counts().index[0]
# Out:
# -5.0

# %% [markdown]
# Also: a quick look at the correlation between the numerical variables is extremely easy with pandas:

# %%
df.corr()
# Out:
#            DayOfWeek  FlightNum  DepDelay   AirTime  Distance
# DayOfWeek   1.000000   0.016484  0.017254  0.027161  0.021530
# FlightNum   0.016484   1.000000  0.024760 -0.335150 -0.349912
# DepDelay    0.017254   0.024760  1.000000  0.013282  0.013871
# AirTime     0.027161  -0.335150  0.013282  1.000000  0.981376
# Distance    0.021530  -0.349912  0.013871  0.981376  1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True, cmap = "coolwarm")

# %% [markdown]
# #### Exercise
#
# What is the plane that has the highest average delay? We'll first group by tail number (the *license plate* of a plane) and then calculate the relevant statistic for each group (group of *departures*)

# %%
delays_per_plane = df.groupby('TailNum')['DepDelay'].mean()

delays_per_plane.sort_values(ascending=False).head(1)
# Out:
# TailNum
# N79011    232.0
# Name: DepDelay, dtype: float64

# %% [markdown]
# Oh, but those numbers smell like these planes had only a few, very delayed, departures! how can we count the number of departures *and* calculate the average delay at the same time?

# %%
delay_stats_per_plane = df.groupby('TailNum')['DepDelay'].agg(['count','mean'])
delay_stats_per_plane.sort_values('mean', ascending = False).head(5)
# Out:
#          count   mean
# TailNum
# N79011       2  232.0
# N228UA       2  217.5
# N707DN       2  204.0
# N651UA       4  167.0
# N776UA       2  159.0

# %% [markdown]
# Awesome! now, let's look at the average delay of the planes with some departures (let's say, at least 15)

# %%
mask = delay_stats_per_plane['count'] >= 15

delay_stats_per_plane[mask].sort_values('mean', ascending = False)
# Out:
#          count        mean
# TailNum
# N398AA      15  118.733333
# N5FSAA      15  105.800000
# N557AA      23   85.434783
# N12125      34   67.235294
# N189DN      20   65.800000
# N619AS      16   62.125000
# N639AA      16   60.312500
# N502MQ      52   59.769231
# N17128      36   52.666667
# N387AA      28   52.500000
# N345AA      17   50.941176
# N41140      41   50.512195
# N5FPAA      15   49.666667
# N367AA      27   49.444444
# N33103      27   47.481481
# N79279      24   47.208333
# N3767       40   46.800000
# N908EV      28   46.250000
# N68452      71   45.535211
# N874AS      77   45.454545
# N5FMAA      20   43.850000
# N469AA      76   43.526316
# N809MQ      31   43.032258
# N210FR     107   40.728972
# N227FR     133   39.593985
# N110SY     106   39.433962
# N407UA      56   39.428571
# N364AA      23   39.130435
# N34137      17   39.117647
# N386AA      28   39.071429
# ...        ...         ...
# N568UW     116   -2.172414
# N594NW      40   -2.200000
# N977DL      15   -2.266667
# N392HA      42   -2.309524
# N564UW     106   -2.311321
# N762AS      73   -2.438356
# N535AS      91   -2.439560
# N609AS     117   -2.598291
# N577AS      83   -2.602410
# N455SW     170   -2.688235
# N395HA      47   -2.702128
# N397AA      18   -2.833333
# N587AS      74   -2.986486
# N383HA      45   -3.000000
# N644AS     124   -3.112903
# N318AS     103   -3.223301
# N779AS      94   -3.234043
# N463SW     127   -3.244094
# N496CA      70   -3.285714
# N796AS     129   -3.356589
# N374HA      54   -3.500000
# N612AS     118   -3.508475
# N183JB      19   -3.684211
# N431SW     122   -3.778689
# N611AS     123   -3.837398
# N659BR     164   -4.097561
# N627AS     103   -4.407767
# N618AS     112   -4.526786
# N299SW      39   -5.769231
# N781CA     146   -5.821918
#
# [4127 rows x 2 columns]

# %% [markdown]
# #### Exercise:
#
# Show cities by descending number of airports

# %%
df
# Out:
#         FlightDate  DayOfWeek Carrier TailNum  FlightNum Origin  \
# 0       2015-01-01          4      AA  N787AA          1    JFK
# 1       2015-01-02          5      AA  N795AA          1    JFK
# 2       2015-01-03          6      AA  N788AA          1    JFK
# 3       2015-01-04          7      AA  N791AA          1    JFK
# 4       2015-01-05          1      AA  N783AA          1    JFK
# 5       2015-01-06          2      AA  N799AA          1    JFK
# 6       2015-01-07          3      AA  N784AA          1    JFK
# 7       2015-01-08          4      AA  N787AA          1    JFK
# 8       2015-01-09          5      AA  N795AA          1    JFK
# 9       2015-01-10          6      AA  N790AA          1    JFK
# 10      2015-01-11          7      AA  N786AA          1    JFK
# 11      2015-01-12          1      AA  N790AA          1    JFK
# 12      2015-01-13          2      AA  N796AA          1    JFK
# 13      2015-01-14          3      AA  N793AA          1    JFK
# 14      2015-01-15          4      AA  N790AA          1    JFK
# 15      2015-01-16          5      AA  N797AA          1    JFK
# 16      2015-01-17          6      AA  N795AA          1    JFK
# 17      2015-01-18          7      AA  N786AA          1    JFK
# 18      2015-01-19          1      AA  N785AA          1    JFK
# 19      2015-01-20          2      AA  N797AA          1    JFK
# 20      2015-01-21          3      AA  N789AA          1    JFK
# 21      2015-01-22          4      AA  N790AA          1    JFK
# 22      2015-01-23          5      AA  N790AA          1    JFK
# 23      2015-01-24          6      AA  N787AA          1    JFK
# 24      2015-01-25          7      AA  N791AA          1    JFK
# 25      2015-01-26          1      AA  N783AA          1    JFK
# 26      2015-01-27          2      AA     NaN          1    JFK
# 27      2015-01-28          3      AA     NaN          1    JFK
# 28      2015-01-29          4      AA  N794AA          1    JFK
# 29      2015-01-30          5      AA  N792AA          1    JFK
# ...            ...        ...     ...     ...        ...    ...
# 469938  2015-01-03          6      NK  N505NK        188    OAK
# 469939  2015-01-04          7      NK  N503NK        188    OAK
# 469940  2015-01-05          1      NK  N508NK        188    OAK
# 469941  2015-01-06          2      NK  N503NK        188    OAK
# 469942  2015-01-07          3      NK  N508NK        188    OAK
# 469943  2015-01-08          4      NK  N503NK        188    OAK
# 469944  2015-01-09          5      NK  N508NK        188    OAK
# 469945  2015-01-10          6      NK  N503NK        188    OAK
# 469946  2015-01-11          7      NK  N508NK        188    OAK
# 469947  2015-01-12          1      NK  N503NK        188    OAK
# 469948  2015-01-13          2      NK  N514NK        188    OAK
# 469949  2015-01-14          3      NK  N528NK        188    OAK
# 469950  2015-01-15          4      NK  N508NK        188    OAK
# 469951  2015-01-16          5      NK  N528NK        188    OAK
# 469952  2015-01-17          6      NK  N508NK        188    OAK
# 469953  2015-01-18          7      NK  N528NK        188    OAK
# 469954  2015-01-19          1      NK  N505NK        188    OAK
# 469955  2015-01-20          2      NK  N521NK        188    OAK
# 469956  2015-01-21          3      NK  N505NK        188    OAK
# 469957  2015-01-22          4      NK  N522NK        188    OAK
# 469958  2015-01-23          5      NK  N502NK        188    OAK
# 469959  2015-01-24          6      NK  N524NK        188    OAK
# 469960  2015-01-25          7      NK  N502NK        188    OAK
# 469961  2015-01-26          1      NK  N524NK        188    OAK
# 469962  2015-01-27          2      NK  N502NK        188    OAK
# 469963  2015-01-28          3      NK  N524NK        188    OAK
# 469964  2015-01-29          4      NK  N502NK        188    OAK
# 469965  2015-01-30          5      NK  N519NK        188    OAK
# 469966  2015-01-31          6      NK  N502NK        188    OAK
# 469967  2015-01-01          4      NK  N502NK        193    IAH
#
#        OriginCityName OriginStateName Dest     DestCityName DestStateName  \
# 0        New York, NY        New York  LAX  Los Angeles, CA    California
# 1        New York, NY        New York  LAX  Los Angeles, CA    California
# 2        New York, NY        New York  LAX  Los Angeles, CA    California
# 3        New York, NY        New York  LAX  Los Angeles, CA    California
# 4        New York, NY        New York  LAX  Los Angeles, CA    California
# 5        New York, NY        New York  LAX  Los Angeles, CA    California
# 6        New York, NY        New York  LAX  Los Angeles, CA    California
# 7        New York, NY        New York  LAX  Los Angeles, CA    California
# 8        New York, NY        New York  LAX  Los Angeles, CA    California
# 9        New York, NY        New York  LAX  Los Angeles, CA    California
# 10       New York, NY        New York  LAX  Los Angeles, CA    California
# 11       New York, NY        New York  LAX  Los Angeles, CA    California
# 12       New York, NY        New York  LAX  Los Angeles, CA    California
# 13       New York, NY        New York  LAX  Los Angeles, CA    California
# 14       New York, NY        New York  LAX  Los Angeles, CA    California
# 15       New York, NY        New York  LAX  Los Angeles, CA    California
# 16       New York, NY        New York  LAX  Los Angeles, CA    California
# 17       New York, NY        New York  LAX  Los Angeles, CA    California
# 18       New York, NY        New York  LAX  Los Angeles, CA    California
# 19       New York, NY        New York  LAX  Los Angeles, CA    California
# 20       New York, NY        New York  LAX  Los Angeles, CA    California
# 21       New York, NY        New York  LAX  Los Angeles, CA    California
# 22       New York, NY        New York  LAX  Los Angeles, CA    California
# 23       New York, NY        New York  LAX  Los Angeles, CA    California
# 24       New York, NY        New York  LAX  Los Angeles, CA    California
# 25       New York, NY        New York  LAX  Los Angeles, CA    California
# 26       New York, NY        New York  LAX  Los Angeles, CA    California
# 27       New York, NY        New York  LAX  Los Angeles, CA    California
# 28       New York, NY        New York  LAX  Los Angeles, CA    California
# 29       New York, NY        New York  LAX  Los Angeles, CA    California
# ...               ...             ...  ...              ...           ...
# 469938    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469939    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469940    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469941    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469942    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469943    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469944    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469945    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469946    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469947    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469948    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469949    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469950    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469951    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469952    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469953    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469954    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469955    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469956    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469957    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469958    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469959    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469960    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469961    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469962    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469963    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469964    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469965    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469966    Oakland, CA      California  LAS    Las Vegas, NV        Nevada
# 469967    Houston, TX           Texas  LAS    Las Vegas, NV        Nevada
#
#        DepTime  DepDelay  AirTime  Distance         DepDateTime
# 0        08:55      -5.0    378.0    2475.0 2015-01-01 08:55:00
# 1        08:50     -10.0    357.0    2475.0 2015-01-02 08:50:00
# 2        08:53      -7.0    330.0    2475.0 2015-01-03 08:53:00
# 3        08:53      -7.0    352.0    2475.0 2015-01-04 08:53:00
# 4        08:53      -7.0    338.0    2475.0 2015-01-05 08:53:00
# 5        08:56      -4.0    335.0    2475.0 2015-01-06 08:56:00
# 6        08:59      -1.0    341.0    2475.0 2015-01-07 08:59:00
# 7        08:56      -4.0    333.0    2475.0 2015-01-08 08:56:00
# 8        09:01       1.0    353.0    2475.0 2015-01-09 09:01:00
# 9        09:03       3.0    345.0    2475.0 2015-01-10 09:03:00
# 10       08:54      -6.0    337.0    2475.0 2015-01-11 08:54:00
# 11       08:53      -7.0    354.0    2475.0 2015-01-12 08:53:00
# 12       08:54      -6.0    336.0    2475.0 2015-01-13 08:54:00
# 13       08:56      -4.0    302.0    2475.0 2015-01-14 08:56:00
# 14       08:52      -8.0    320.0    2475.0 2015-01-15 08:52:00
# 15       09:00       0.0    321.0    2475.0 2015-01-16 09:00:00
# 16       08:52      -8.0    343.0    2475.0 2015-01-17 08:52:00
# 17       09:16      16.0    340.0    2475.0 2015-01-18 09:16:00
# 18       08:54      -6.0    359.0    2475.0 2015-01-19 08:54:00
# 19       08:53      -7.0    349.0    2475.0 2015-01-20 08:53:00
# 20       08:53      -7.0    327.0    2475.0 2015-01-21 08:53:00
# 21       08:52      -8.0    324.0    2475.0 2015-01-22 08:52:00
# 22       08:54      -6.0    328.0    2475.0 2015-01-23 08:54:00
# 23       10:43     103.0    323.0    2475.0 2015-01-24 10:43:00
# 24       09:03       3.0    308.0    2475.0 2015-01-25 09:03:00
# 25       08:54      -6.0    337.0    2475.0 2015-01-26 08:54:00
# 26       00:00       NaN      NaN    2475.0 2015-01-27 00:00:00
# 27       00:00       NaN      NaN    2475.0 2015-01-28 00:00:00
# 28       08:55      -5.0    349.0    2475.0 2015-01-29 08:55:00
# 29       08:58      -2.0    352.0    2475.0 2015-01-30 08:58:00
# ...        ...       ...      ...       ...                 ...
# 469938   05:57      -3.0     61.0     407.0 2015-01-03 05:57:00
# 469939   05:54      -6.0     65.0     407.0 2015-01-04 05:54:00
# 469940   05:50     -10.0     64.0     407.0 2015-01-05 05:50:00
# 469941   05:58      -2.0     68.0     407.0 2015-01-06 05:58:00
# 469942   05:59      -1.0     71.0     407.0 2015-01-07 05:59:00
# 469943   05:53      -7.0     67.0     407.0 2015-01-08 05:53:00
# 469944   05:53      -7.0     69.0     407.0 2015-01-09 05:53:00
# 469945   05:50     -10.0     62.0     407.0 2015-01-10 05:50:00
# 469946   05:52      -8.0     66.0     407.0 2015-01-11 05:52:00
# 469947   05:54      -6.0     64.0     407.0 2015-01-12 05:54:00
# 469948   06:03       3.0     66.0     407.0 2015-01-13 06:03:00
# 469949   05:54      -6.0     66.0     407.0 2015-01-14 05:54:00
# 469950   05:57      -3.0     61.0     407.0 2015-01-15 05:57:00
# 469951   05:52      -8.0     63.0     407.0 2015-01-16 05:52:00
# 469952   05:55      -5.0     62.0     407.0 2015-01-17 05:55:00
# 469953   05:51      -9.0     61.0     407.0 2015-01-18 05:51:00
# 469954   05:50     -10.0     63.0     407.0 2015-01-19 05:50:00
# 469955   05:54      -6.0     63.0     407.0 2015-01-20 05:54:00
# 469956   05:56      -4.0     66.0     407.0 2015-01-21 05:56:00
# 469957   05:55      -5.0     63.0     407.0 2015-01-22 05:55:00
# 469958   05:55      -5.0     66.0     407.0 2015-01-23 05:55:00
# 469959   05:52      -8.0     67.0     407.0 2015-01-24 05:52:00
# 469960   05:54      -6.0     68.0     407.0 2015-01-25 05:54:00
# 469961   05:51      -9.0     71.0     407.0 2015-01-26 05:51:00
# 469962   05:49     -11.0     65.0     407.0 2015-01-27 05:49:00
# 469963   06:03       3.0     64.0     407.0 2015-01-28 06:03:00
# 469964   05:56      -4.0     64.0     407.0 2015-01-29 05:56:00
# 469965   05:56      -4.0     66.0     407.0 2015-01-30 05:56:00
# 469966   06:01       1.0     69.0     407.0 2015-01-31 06:01:00
# 469967   07:43      43.0    167.0    1222.0 2015-01-01 07:43:00
#
# [469968 rows x 16 columns]

# %%
df[df['OriginCityName'] == "New York, NY"]['Origin'].unique()
# Out:
# array(['JFK', 'LGA'], dtype=object)

# %%
#print(df.groupby('OriginCityName')['Origin'].unique().map(lambda x:len(x)).sort_values(ascending = True).head(10))

# Other way:
airports_per_city = df.groupby('OriginStateName')['Origin'].nunique()
airports_per_city.sort_values(ascending = False).head(10)
# Out:
# OriginStateName
# Texas             24
# California        22
# Florida           17
# Alaska            16
# Michigan          15
# New York          12
# Colorado          10
# North Carolina     8
# North Dakota       8
# Minnesota          8
# Name: Origin, dtype: int64

# %% [markdown]
# ### Plotting
#
# There are several ways in which we could go about plotting this dataset in order to get acquainted with it.

# %% [markdown]
# For example, do the delays have a relationship with the number of departures a plane does?

# %% [markdown]
# #### Exercise
#
# Do a scatter plot with matplotlib. Check the documentation

# %%
data = df.groupby('TailNum')['DepDelay'].agg(['count','median'])

plt.scatter('count','median',data = data, alpha = .1)
plt.show()

# %% [markdown]
# Pretty impossible to see anything in there. Maybe a different kind of plottting is required:

# %%
delay_stats_per_plane.plot.scatter('count','mean', alpha = 0.1)
plt.show()

# %%
plt.scatter('count','median',data = data, alpha = .25)
plt.ylim([0.1, 1000])
plt.xlim([0, 200])
plt.semilogy()
plt.show()

# %%
ax = delay_stats_per_plane.plot.hexbin('count','mean')
ax.set_xlim(0,250)
ax.set_ylim(-20,50)
plt.show()

# %% [markdown]
# #### Exercise:
#
# Plot the distribution of delays as a histogram, both with a linear and a logarithmic scale

# %%
np.isnan(df['DepDelay']).value_counts()
# Out:
# False    458311
# True      11657
# Name: DepDelay, dtype: int64

# %%
data = df[~np.isnan(df['DepDelay'])]['DepDelay']
plt.hist(data,bins = range(-10,250,5), alpha = 0.5)
plt.show()

# %%
delays = df['DepDelay'][df['DepDelay']>0]

np.log10(delays).hist(bins=np.linspace(0,3,25), alpha = 0.5)
plt.show()

# %%
data = df[~np.isnan(df['DepDelay'])]['DepDelay']
plt.hist(data,bins = 1000, alpha = 0.5)
plt.semilogx()
plt.ylim([0, 25000])
plt.show()

# %% [markdown]
# ### Another question:
#
# how do the delays stack over the course of the day? We are going to look at it by plotting the distribution of delays for each hour of the day. The very best way to compare distributions side by side is a boxplot, so we'll use that.

# %% [markdown]
# We need to provide `plt.boxplot()` with a sequence that contains 24 elements. Each of those will be a sequence containing every individual delay for one hour of the day. We'll need, therefore, to extract hours of the day for each departure and group based on that.

# %%
data = pd.DataFrame({'Delay':df['DepDelay'], 'Hour':df['DepDateTime'].map(lambda x: x.hour)})

# %%
fig, ax = plt.subplots()

fig.set_size_inches(15,10)

sns.boxplot(x = 'Hour', y = 'Delay', data = data, fliersize = 0.5, whis = 3, width = 0.5, linewidth = 0.5)
plt.ylim([-100, 500])

plt.show()

# %% [markdown]
# ### Everything looks ok! let's plot this thing!
